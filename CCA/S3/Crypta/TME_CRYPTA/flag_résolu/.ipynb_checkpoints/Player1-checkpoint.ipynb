# %%
import base64
import gmpy2
import random

# %%
def commit():
    choix = ["PIERRE","CISEAUX","FEUILLE"]
    p=gmpy2.mpz('...',16)
    g=gmpy2.mpz(2)
    i=gmpy2.mpz('CE45361C55D07CB8A163E6328665B3DC2007CB8A163E6492B1F1E',16)
    q=gmpy2.powmod(g,i,p)
    print("GROUP",hex(p)[2:],g,hex(q)[2:],"\n")
    #clé secrète
    x=gmpy2.mpz("...",16)
    #clé publique
    h=gmpy2.powmod(g,x,p)
    print("PKEY",hex(h))
    #produire aléatoire
    y=random.randint(1,q-1)
    coup=random.choice(choix)
    m = int(bytes(coup, encoding='utf-8').hex(), 16)
    c1 = gmpy2.powmod(g,y,p)
    c2=gmpy2.f_mod(gmpy2.mul(m,gmpy2.powmod(c1,x,p)), p)
    #c2 =  gmpy2.f_mod(gmpy2.mul(m,gmpy2.powmod(h,y,p)), p)
    print("COMMIT",hex(c1)[2:],hex(c2)[2:])
    print("MOVE",coup)
    print("OPEN",hex(y)[2:])

# %%
commit()
# Out:
# GROUP ... 2 ...
#
# PKEY ...
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...

# %%
#input_string = "FFFFFFFF FFFFFFFF C90FDAA2 2168C234 C4C6628B 80DC1CD129024E08 8A67CC74 020BBEA6 3B139B22 514A0879 8E3404DDEF9519B3 CD3A431B 302B0A6D F25F1437 4FE1356D 6D51C245E485B576 625E7EC6 F44C42E9 A637ED6B 0BFF5CB6 F406B7EDEE386BFB 5A899FA5 AE9F2411 7C4B1FE6 49286651 ECE45B3DC2007CB8 A163BF05 98DA4836 1C55D39A 69163FA8 FD24CF5F83655D23 DCA3AD96 1C62F356 208552BB 9ED52907 7096966D670C354E 4ABC9804 F1746C08 CA18217C 32905E46 2E36CE3BE39E772C 180E8603 9B2783A2 EC07A28F B5C55DF0 6F4C52C9DE2BCBF6 95581718 3995497C EA956AE5 15D22618 98FA051015728E5A 8AAAC42D AD33170D 04507A33 A85521AB DF1CBA64ECFB8504 58DBEF0A 8AEA7157 5D060C7D B3970F85 A6E1E4C7ABF5AE8C DB0933D7 1E8C94E0 4A25619D CEE3D226 1AD2EE6BF12FFA06 D98A0864 D8760273 3EC86A64 521F2B18 177B200CBBE11757 7A615D6C 770988C0 BAD946E2 08E24FA0 74E5AB3143DB5BFC E0FD108E 4B82D120 A93AD2CA FFFFFFFF FFFFFFFF"


input_string ="FFFFFFFF FFFFFFFF C90FDAA2 2168C234 C4C6628B 80DC1CD129024E08 8A67CC74 020BBEA6 3B139B22 514A0879 8E3404DDEF9519B3 CD3A431B 302B0A6D F25F1437 4FE1356D 6D51C245E485B576 625E7EC6 F44C42E9 A637ED6B 0BFF5CB6 F406B7EDEE386BFB 5A899FA5 AE9F2411 7C4B1FE6 49286651 ECE45B3DC2007CB8 A163BF05 98DA4836 1C55D39A 69163FA8 FD24CF5F83655D23 DCA3AD96 1C62F356 208552BB 9ED52907 7096966D670C354E 4ABC9804 F1746C08 CA18217C 32905E46 2E36CE3BE39E772C 180E8603 9B2783A2 EC07A28F B5C55DF0 6F4C52C9DE2BCBF6 95581718 3995497C EA956AE5 15D22618 98FA051015728E5A 8AAAC42D AD33170D 04507A33 A85521AB DF1CBA64ECFB8504 58DBEF0A 8AEA7157 5D060C7D B3970F85 A6E1E4C7ABF5AE8C DB0933D7 1E8C94E0 4A25619D CEE3D226 1AD2EE6BF12FFA06 D98A0864 D8760273 3EC86A64 521F2B18 177B200CBBE11757 7A615D6C 770988C0 BAD946E2 08E24FA0 74E5AB3143DB5BFC E0FD108E 4B82D120 A9210801 1A723C12 A787E6D788719A10 BDBA5B26 99C32718 6AF4E23C 1A946834 B6150BDA2583E9CA 2AD44CE8 DBBBC2DB 04DE8EF9 2E8EFC14 1FBECAA6287C5947 4E6BC05D 99B2964F A090C3A2 233BA186 515BE7ED1F612970 CEE2D7AF B81BDD76 2170481C D0069127 D5B05AA993B4EA98 8D8FDDC1 86FFB7DC 90A6C08F 4DF435C9 34063199"

# 使用 join 方法去除空格
output_string = "".join(input_string.split())

print(output_string)
# Out:
# ...

# %%
def commit_hard():
    
    choix = ["PIERRE","CISEAUX","FEUILLE"]
    #p=gmpy2.mpz('...',16)   
    p_bis=gmpy2.mpz("...",16)
    g=gmpy2.mpz(2)
    i=gmpy2.mpz('CE45361C55D07CB8A1AB163E6328665B3DC2007CB8A163E61235380dcceac1235380d492B1F1E',16)
    #q=hex(gmpy2.powmod(g,i,p))
    q_bis=gmpy2.powmod(g,i,p_bis)
    print("GROUP",hex(p_bis)[2:],g,q_bis[2:],"\n")
    #clé secrète
    x=gmpy2.mpz("...",16)
    #clé publique
    h=gmpy2.powmod(g,x,p_bis)
    print("PKEY",hex(h)[2:])
    #produire aléatoire
    for i in range(100):
        y=random.randint(1, q_bis-1)
        coup=random.choice(choix)
        m = int(bytes(coup, encoding='utf-8').hex(), 16)
        c1 = gmpy2.powmod(g,y,p_bis)
        c2 =  gmpy2.f_mod(gmpy2.mul(m,gmpy2.powmod(h,y,p_bis)), p_bis)
        #c2=gmpy2.f_mod(gmpy2.mul(m,gmpy2.powmod(c1,x,p_bis)), p_bis)
        print("COMMIT",hex(c1)[2:],hex(c2)[2:])
        print("MOVE",coup)
        print("OPEN",hex(y)[2:])
        print("MOVE",random.choice(choix))
        print("OK")

# %%
commit_hard()
# Out:
# GROUP ... 2 ...
#
# PKEY ...
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE FEUILLE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE PIERRE
# OPEN ...
# MOVE CISEAUX
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE CISEAUX
# OPEN ...
# MOVE PIERRE
# OK
# COMMIT ... ...
# MOVE FEUILLE
# OPEN ...
# MOVE CISEAUX
# OK
