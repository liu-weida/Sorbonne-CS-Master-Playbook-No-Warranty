# %%
import base64
import gmpy2
import random

# %%
def return_h():
    h_hex = input("enter h")
    return gmpy2.mpz(h_hex,16)

# %%
def verification(h):
    g=gmpy2.mpz(2)
    p=gmpy2.mpz('...',16)
    #enter c1 and c2
    coup = input("enter coup")
    m=int(bytes(coup, encoding='utf-8').hex(), 16)
    c1_hex = input("enter c1")
    c2_hex = input("enter c2")
    c1=gmpy2.mpz(c1_hex,16)
    c2=gmpy2.mpz(c2_hex,16)
    #enter alea y 
    y_hex = input("enter y")
    y=gmpy2.mpz(y_hex,16)
    if (c1==gmpy2.powmod(g,y,p)) and (c2==gmpy2.f_mod(gmpy2.mul(m,gmpy2.powmod(h,y,p)), p)):
    #c2==gmpy2.f_mod(m * gmpy2.powmod(h,y,p), p):
        print("OK")
    else:
        print("REFEREE")

# %%
h = return_h()
# Out:
# enter h ...

# %%
verification(h)
# Out:
# enter coup CISEAUX
# enter c1 ...
# enter c2 ...
# enter y ...
# OK
