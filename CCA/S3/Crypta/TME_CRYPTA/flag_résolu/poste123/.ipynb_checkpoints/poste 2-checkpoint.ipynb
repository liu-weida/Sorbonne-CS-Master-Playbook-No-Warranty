# %%
import gmpy2
from fpylll import IntegerMatrix, LLL
x=gmpy2.mpz("",16)       
p=gmpy2.mpz("",16)
M = IntegerMatrix(2, 2)
M[0, 0] = 1
M[0, 1] = int(x)            
M[1, 0] = 0
M[1, 1] = int(p)
M_LLL = LLL.reduction(M)
short_vector = M_LLL[0]
norm_short_vector = short_vector.norm()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/yijiezheng/Desktop/TME CRYPTA/flag_résolu/poste123/poste 2.ipynb 单元格 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/yijiezheng/Desktop/TME%20CRYPTA/flag_re%CC%81solu/poste123/poste%202.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import gmpy2
#       <a href='vscode-notebook-cell:/Users/yijiezheng/Desktop/TME%20CRYPTA/flag_re%CC%81solu/poste123/poste%202.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from fpylll import IntegerMatrix, LLL
#       <a href='vscode-notebook-cell:/Users/yijiezheng/Desktop/TME%20CRYPTA/flag_re%CC%81solu/poste123/poste%202.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> x=gmpy2.mpz("",16)
#
# ModuleNotFoundError: No module named 'gmpy2'

# %%
print("b:"+short_vector[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yijiezheng/Desktop/TME CRYPTA/flag_résolu/poste123/poste 2.ipynb 单元格 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/yijiezheng/Desktop/TME%20CRYPTA/flag_re%CC%81solu/poste123/poste%202.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> print("b:"+short_vector[1])
#
# NameError: name 'short_vector' is not defined

# %%
#short_vector=(b,a)
