# %%
r=int("",16)

# %%
r
# Out:
# 

# %%
e = int("0x10001",16)

# %%
N=int("",16)

# %%
c=int("",16)

# %%
J=int("",16)

# %%
y=int("",16)

# %%
import gmpy2

# %%
e=gmpy2.mpz(e)

# %%
N=gmpy2.mpz(N)

# %%
c=gmpy2.mpz(c)

# %%
J=gmpy2.mpz(J)

# %%
y=gmpy2.mpz(y)

# %%
gmpy2.powmod(J, c, N)
# Out:
# mpz()

# %%
gmpy2.powmod(J, c*(e-1), N)
# Out:
# mpz()

# %%
x=hex(gmpy2.powmod(J, c*(e-1), N))
x
# Out:
# ''

# %%
y=hex(gmpy2.powmod(J, c, N))
y
# Out:
# ''
