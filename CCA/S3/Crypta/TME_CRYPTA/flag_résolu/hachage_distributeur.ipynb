# %%
from hashlib import sha256

# Trouver 2 chaines qui commence par le même nom
# Hash des 2 chaines, les 56 premiers bits sont égaux
# Donc il y a plusieurs clé possible

# Les 2 chaines = 2 clés

# Faut juste trouver le même Hash pour les 2 chaines


# f = la fonction qu'on doit écrire qui fait le hash et qui renvoie les 56 premiers bits
# x0 = le point de départ : un mot aléatoire

def floyd(f, x0):
    """Floyd's cycle detection algorithm."""
    # Main phase of algorithm: finding a repetition x_i = x_2i.
    # The hare moves twice as quickly as the tortoise and
    # the distance between them increases by 1 at each step.
    # Eventually they will both be inside the cycle and then,
    # at some point, the distance between them will be
    # divisible by the period λ.
    tortoise = f(x0)  # f(x0) is the element/node next to x0.
    hare = f(f(x0))
    while tortoise != hare:
        tortoise = f(tortoise)
        hare = f(f(hare))

    # At this point the tortoise position, ν, which is also equal
    # to the distance between hare and tortoise, is divisible by
    # the period λ. So hare moving in cycle one step at a time,
    # and tortoise (reset to x0) moving towards the cycle, will
    # intersect at the beginning of the cycle. Because the
    # distance between them is constant at 2ν, a multiple of λ,
    # they will agree as soon as the tortoise reaches index μ.


    tortoise = x0
    while tortoise != hare:
        m1 = tortoise  # l'étape juste avant car c'est la clé, et l'étape d'après ça hash et ça détecte la colision
        tortoise = f(tortoise)
        hare = f(hare)   # Hare and tortoise move at same speed

    hare = f(tortoise)
    while tortoise != hare:
        m2 = hare
        hare = f(hare)

    prefix = "Kaylani"
    m1 = prefix + m1
    m2 = prefix + m2
    print(m1.encode().hex(), m2.encode().hex())


def f(x):
    Pref = "Kaylani"
    x = Pref + x
    # Calculer le hash de x
    # retourne les 56 premiers bits
    return sha256(x.encode()).hexdigest()[:14]  # 56 bits = 14 hexa = 14*4 = 56 bits


floyd(f, "Jussieu")
# Out:
# 4b61796c616e693837336633353663356439353435 4b61796c616e693662343039613236393430643361

# %%
from hashlib import sha256

def f(x):
    prefix = "Abby"
    x = prefix + x  # 将前缀和当前字符串合并
    return sha256(x.encode()).hexdigest()[:14]  # 返回56位的SHA256散列的十六进制前14位

def floyd(f, x0):
    tortoise = f(x0)
    hare = f(f(x0))
    while tortoise != hare:
        tortoise = f(tortoise)
        hare = f(f(hare))

    tortoise = x0
    while tortoise != hare:
        tortoise = f(tortoise)
        hare = f(hare)

    m1 = tortoise
    hare = f(tortoise)
    m2 = hare

    while tortoise != hare:
        hare = f(hare)
        m2 = hare

    print(f"First value (m1): {m1.encode().hex()}")
    print(f"Second value (m2): {m2.encode().hex()}")

floyd(f, "Jussieu")
# Out:
# First value (m1): 3463626434636464386234313833
# Second value (m2): 3463626434636464386234313833
